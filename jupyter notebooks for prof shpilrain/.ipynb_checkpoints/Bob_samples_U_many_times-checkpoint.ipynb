# %%
import numpy as np
import random
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn as sk
from pathlib import Path

# %%
#Let's experimentally determine the threshold by having Bob run the protocol in specific cases.
#This protocol has been modified to have Bob take several (q) individual selections from U.

n = 700000 #size of Bob and Alice's set
k = 8 #size of U
mu = 20000 #mean of distro 
mu2 = 50000
num_trials = 1500
q = 250 #number of times bob selects from U
s_start = 10000
s_end = 10000000

U = np.random.exponential(scale=mu, size = k) #Bob's set. This is also when U is determined for the protocol below.

candidate_list_U = []

#Run protocol several times to get a dataset of E-S/n values.

for i in range(num_trials):
    
    S = random.randint(s_start, s_end) #Bob's random number

    bob_select_list = []
    for j in range (q):
        bobChoice  = random.sample(tuple(U),1)[0] #samples 1 times from U
        bob_select_list.append(bobChoice)

    aliceSum = int(sum(bob_select_list)) + S #combines Bob's samples with his private key to be sent to Alice

    aliceSample = np.random.exponential(scale=mu, size = int(n-q)) #alice fills out the transmission with n-q samples of her distribution

    A = (aliceSum+sum(aliceSample))/n #Alice takes the mean

    E = A - mu #Subtracts the mean of her distribution
    
    threshold_candidate = abs(E - S/n) #This is what Bob computes when he receives E.

    candidate_list_U.append(threshold_candidate) #Adds the result to a list

experimental_threshold_U = np.percentile(candidate_list_U, 80) #This is the threshold value that gives a success rate of 0.8
print(f"The 80th percentile for a threshold where they use U is: {experimental_threshold_U}")

#As a note, running the above with the 30th percentile also retrieves a success rate very close to 1 --> 0.99 approximately 

#We can perform the same computation for distribution 2 if we'd like, and compare.
"""
candidate_list_V = []
bob_select_list=[]
V = np.random.exponential(scale=mu2, size = k) #Bob's set.

for i in range(num_trials):
    
    S = random.randint(s_start,s_end) #Bob's random number

    bob_select_list = []
    for j in range (q):
        bobChoice  = random.sample(tuple(V),1)[0] #samples 1 time from V
        bob_select_list.append(bobChoice)
        
    aliceSum = int(sum(bob_select_list)) + S #combines Bob's samples with his private key to be sent to Alice

    aliceSample = np.random.exponential(scale=mu2, size = int(n-q)) #alice fills out the transmission with n-q samples of her distribution

    A = (aliceSum+sum(aliceSample))/n #Alice takes the mean

    E = A - mu2 #Subtracts the mean of her distribution
    
    threshold_candidate = abs(E - S/n) #This is what Bob computes when he receives E.

    candidate_list_V.append(threshold_candidate) #Adds the result to a list

experimental_threshold_V = np.percentile(candidate_list_V, 80) #This is the threshold value that gives a success rate of 0.8
print(f"The 80th percentile for a threshold where they use V is: {experimental_threshold_V}")



#Now what if Bob and Alice's dstributions don't agree? Let Bob have distro 1 (i.e. U)
#and Alice has distro 2 (i.e. V)

candidate_list_disagree = []
bob_select_list=[]
for i in range(num_trials):
    
    S = random.randint(s_start,s_end) #Bob's random number
    bob_select_list=[0]
    for b in range(q):
        bobChoice  = random.sample(tuple(U),1)[0] #samples 1 time from U
        bob_select_list.append(bobChoice)

    aliceSum = int(sum(bob_select_list)) + S #combines Bob's samples with his private key to be sent to Alice

    aliceSample = np.random.exponential(scale=mu2, size = int(n-q)) #alice fills out the transmission with n-k samples of her distribution

    A = (aliceSum+sum(aliceSample))/n #Alice takes the mean

    E = A - mu2 #Subtracts the mean of her distribution
    
    threshold_candidate = abs(E - S/n) #This is what Bob computes when he receives E.

    candidate_list_disagree.append(threshold_candidate) #Adds the result to a list

experimental_threshold_disagree = np.percentile(candidate_list_disagree, 80) #This is the threshold value that gives a success rate of 0.8
"""
#print(f"The 80th percentile for a threshold where they disagree is: {experimental_threshold_disagree}")

#print(f"The minimum result for when they disagree was {min(candidate_list_disagree)}")
print(f"The minimum result for when they agree (U) was {min(candidate_list_U)}")
#print(f"The maximum result for when they disagree was {max(candidate_list_disagree)}")
print(f"The maximum result for when they agree (U) was {max(candidate_list_U)}")
#print(f"The minimum result for when they agree (V) is {min(candidate_list_V)}")
#print(f"The maximum result for when they agree (V) is {max(candidate_list_V)}")
# Out:
# The 80th percentile for a threshold where they use U is: 31.038167052906132
# The minimum result for when they agree (U) was 0.00340371078673396
# The maximum result for when they agree (U) was 76.75873704140857

# %%
#This code will have Bob select a single value from the set U q times. A candidate value for q is 100.
#As with the other protocols, we are starting with the exponential distribution.
#Parameter values are:

n = 700000 #Total size of selection of bob and alice combined
k = 8 #Size of set U
q = 250 #Number of selections bob makes from U
mu1 = 20000 #mean of distribution U
mu2 = 50000 #mean of distribution V
S_start = 10000 #Lower bound of bob's range for private key
S_end = 10000000 #Upper bound of bob's range for private key
num_trials = 2000 #Number of times experiment is run

# %%
#The protocol is now run where Bob selects 100 individual values from U.
success_rate = 0
failure_rate = 0
inconclusive_rate = 0

bob_guess_set = [] #initializing a sanity check to ensure Bob and Alice retrieve exact same set
alice_choice_set = []

selection_sums = []
alice_selection_sums = []
for i in range(num_trials): #run the whole protocol a specified number of times
    
    bob_selection = []
    for i in range(q): # create bob's selection list
        selection = random.choice(tuple(U))
        bob_selection.append(selection)

    selection_sums.append(sum(bob_selection)) # Create list of the values of Bob's sum.
    
    S = random.randint(S_start, S_end) #Bob's private key

    bob_transmission = sum(bob_selection) + S #This is sent to Alice

    alice_choice = random.choice(["U", "V"])

    if alice_choice == "U":
        alice_addition = np.random.exponential(scale=mu1, size=n-q)
        total_sum = sum(alice_addition) + bob_transmission
        A = total_sum/n
        E = A - mu1
    elif alice_choice == "V":
        alice_addition = np.random.exponential(scale=mu2, size=n-q)
        total_sum = sum(alice_addition) + bob_transmission
        A = total_sum/n
        E = A - mu2

    alice_choice_set.append(alice_choice) #This is to track Alice's choices
    alice_selection_sums.append(sum(alice_addition)) #This is to track the value of Alice's selection
    
    #This is sent back to Bob. 

    bob_value = abs(E - S/n)

    if bob_value <= experimental_threshold_U:
        bob_guess = "U"
    else:
        bob_guess = "V"

    bob_guess_set.append(bob_guess)
    
    if (alice_choice == bob_guess):
        success_rate += 1
    elif alice_choice != bob_guess:
        failure_rate += 1
    else:
        inconclusive_rate += 1
        
print(f"The experimental threshold is: {experimental_threshold_U}")
print(f"The success rate is: {success_rate/num_trials}")
print(f"The failure rate is: {failure_rate/num_trials}")
print(f"The inconclusive rate is: {inconclusive_rate/num_trials}")

print(success_rate/num_trials + failure_rate/num_trials + inconclusive_rate/num_trials)
print("")
print("Bob's selection diagnostics:")
print(f"Average value of his sum: {sum(selection_sums)/num_trials}")
print(f"Min value of his sum: {min(selection_sums)}")
print(f"Max value of his sum: {max(selection_sums)}")
print("")
print("Alice's selection diagnostics:")
print(f"Average value of her addition: {sum(alice_selection_sums)/num_trials}")
print(f"Ratio of Bob's signal to alice's addition (Not including bob's private key): {(sum(selection_sums)/num_trials)/(sum(alice_selection_sums)/num_trials)}")
print("")
print("Information about set U")
print(f"The set U is : {U}")
print(f"The mean of U is:{sum(U)/k}")
print("")
print(f"Are Bob's set of guesses and Alice's random selections the same: {bob_guess_set == alice_choice_set}")
# Out:
# The experimental threshold is: 31.038167052906132
# The success rate is: 0.728
# The failure rate is: 0.272
# The inconclusive rate is: 0.0
# 1.0
#
# Bob's selection diagnostics:
# Average value of his sum: 3485727.600256793
# Min value of his sum: 3049972.943477372
# Max value of his sum: 3928135.268090347
#
# Alice's selection diagnostics:
# Average value of her addition: 24648493028.12113
# Ratio of Bob's signal to alice's addition (Not including bob's private key): 0.00014141747312016088
#
# Information about set U
# The set U is : [29874.87765047 22743.77099691  7540.40409925  2860.73136048
#   7444.65851267 15168.24774329 18859.42684708  7069.77593156]
# The mean of U is:13945.236642712534
#
# Are Bob's set of guesses and Alice's random selections the same: False

# %%
Q1 = np.percentile(selection_sums, 25)
Q3 = np.percentile(selection_sums, 75)
IQR = Q3 - Q1

#Define non-outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#Filter data and find the boundaries
non_outliers = []
outlier_count = 0
for i in range(len(selection_sums)):
    if (selection_sums[i] >= lower_bound) and (selection_sums[i]<= upper_bound):
        non_outliers.append(selection_sums[i])
    else:
        outlier_count += 1

plt.boxplot(selection_sums, vert=False, patch_artist=True, flierprops=dict(marker='s', markerfacecolor='red'))
plt.axvline(min(non_outliers), linestyle=":", label = f"Minimum: {round(min(non_outliers),0)}")
plt.axvline(max(non_outliers), linestyle=":", label = f"Maximum: {round(max(non_outliers),0)}")
plt.axvline(np.percentile(non_outliers,50), linestyle=":", label = f"Median: {round(np.percentile(non_outliers,50),0)}")
plt.axvline(Q1, linestyle=":", label = f"First Quartile: {round(Q1,0)}")
plt.axvline(Q3, linestyle=":", label = f"Third Quartile: {round(Q3,0)}")
plt.xlabel("Values of sum of Bob's selection")
plt.yticks([])
plt.xticks(np.round(np.linspace(min(selection_sums)-10000, max(selection_sums)+10000, 7),0))
plt.legend()
plt.show()
print(f"There are {outlier_count} fliers")
#This goes through some preprocessing - taking out outliers (here called fliers) which are minimal
# Out:
# There are 21 fliers

# %%
#Let's see what an eavesdropper can do in this scenario
#Let Eve be an eavesdropper who samples the public sample U n times and takes the mean.
#Let's also try and visualize the distribution over several iterations of this protocol.

#Reestablish U and parameters
mu = 20000
k = 8
n = 250 #number of times eve samples U
p = 40 #number of times protocol is run
#U = np.random.exponential(scale=mu, size = k)
print(f"The set U is : {U}")

#This code will calculate eve's average of her samples, and then store it in a list which is plotted below over p trials.
many_samples = []
for j in range(p):

    eve_samples = []
    
    for i in range(n):
        choice = random.sample(tuple(U),1)[0]
        eve_samples.append(choice)
    
    eve_sum = sum(eve_samples)
    eve_avg = eve_sum/n
    many_samples.append(eve_avg)
    
    print(f"The average of Eve's samples is : {eve_avg}")

x_axis = range(p)
plt.scatter(x_axis, many_samples)
plt.axhline(mu, linestyle = "--", color="grey", label = f"Private mean: {mu}")
plt.axhline(sum(U)/len(U), linestyle = "--", color="black", label = f"Mean of U: {round(sum(U)/len(U), 0)}")
plt.xlabel("Trial #")
plt.ylabel("Mean of sample")
plt.title(f"Eve's mean for {n} samples over {p} trials")
plt.legend()
plt.show()
# Out:
# The set U is : [29874.87765047 22743.77099691  7540.40409925  2860.73136048
#   7444.65851267 15168.24774329 18859.42684708  7069.77593156]
# The average of Eve's samples is : 14388.147793376866
# The average of Eve's samples is : 13457.643094462135
# The average of Eve's samples is : 12696.915081253426
# The average of Eve's samples is : 14270.284361567763
# The average of Eve's samples is : 13842.738726012334
# The average of Eve's samples is : 13866.422878909329
# The average of Eve's samples is : 13432.087519832488
# The average of Eve's samples is : 13797.97929001958
# The average of Eve's samples is : 13312.488384280725
# The average of Eve's samples is : 13825.092589857684
# The average of Eve's samples is : 13666.75219657852
# The average of Eve's samples is : 14242.742385047315
# The average of Eve's samples is : 14110.883729436358
# The average of Eve's samples is : 13253.485261231805
# The average of Eve's samples is : 14437.447506241895
# The average of Eve's samples is : 14007.181060214389
# The average of Eve's samples is : 14076.767395205978
# The average of Eve's samples is : 13515.941094175267
# The average of Eve's samples is : 13875.241306072763
# The average of Eve's samples is : 14011.590598082033
# The average of Eve's samples is : 14260.050362943532
# The average of Eve's samples is : 14465.136088876696
# The average of Eve's samples is : 14273.282917152408
# The average of Eve's samples is : 14315.981177950056
# The average of Eve's samples is : 15237.819163496508
# The average of Eve's samples is : 13972.610754371095
# The average of Eve's samples is : 15307.490790419428
# The average of Eve's samples is : 13830.960148180377
# The average of Eve's samples is : 14733.368704689874
# The average of Eve's samples is : 14368.486398259263
# The average of Eve's samples is : 13699.382816449857
# The average of Eve's samples is : 13629.89180015555
# The average of Eve's samples is : 13931.575776527023
# The average of Eve's samples is : 13853.908012045851
# The average of Eve's samples is : 13742.864937847424
# The average of Eve's samples is : 13535.782615959923
# The average of Eve's samples is : 13813.643341683466
# The average of Eve's samples is : 14147.59552347362
# The average of Eve's samples is : 14439.97783961562
# The average of Eve's samples is : 13022.775214175586

# %%
print(bob_transmission)
print(eve_sum)
approximate_S = abs(bob_transmission-eve_sum)
print(approximate_S)
print(S)
print(eve_samples[:10])
# Out:
# 4396790.258993531
# 3255693.8035438964
# 1141096.4554496342
# 836987
# [np.float64(22743.77099690697), np.float64(2860.731360480399), np.float64(7540.404099252355), np.float64(22743.77099690697), np.float64(29874.87765046957), np.float64(22743.77099690697), np.float64(22743.77099690697), np.float64(29874.87765046957), np.float64(7444.65851266633), np.float64(7444.65851266633)]

# %%
print(bob_selection[:10])
# Out:
# [np.float64(7540.404099252355), np.float64(2860.731360480399), np.float64(18859.426847077677), np.float64(7444.65851266633), np.float64(7069.775931555062), np.float64(18859.426847077677), np.float64(18859.426847077677), np.float64(7540.404099252355), np.float64(29874.87765046957), np.float64(18859.426847077677)]
